# %% [markdown]
# <a href="https://colab.research.google.com/github/poresiddhi-code/07-function.ipynb/blob/main/07_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Functions

# %% [markdown]
# What is function
# As the name says, function is something that has a function (i.e. purpose)
#
# In other words, a function must have a clear definition otherwise it cannot function properly!

# %%
# Let's define simple function

def hello():
    print('hello world')

# this won't output anything, because we haven't called the function yet

# %% [markdown]
# Example

# %%
# Let's define simple function

def hello():
    print('world')

# this won't output anything, because we haven't called the function yet

# %%
hello()   # the above defined function is now called. Hence the output

# %% [markdown]
# example

# %%
def greet():
    print("Hello Siddhi")

greet()

# %%
def add_numbers():
    a = 10
    b = 20
    print(a + b)

add_numbers()

# %% [markdown]
# So what can we say about function now?
#
# A function can be defined as the organized block of reusable code, which can be called whenever required.
#
# Functions start with keyword def followed by function_name() And end with : followed by indentation.
#
# Functions allow reusability of the code as we can call Python functions multiple times anywhere in a program.
#
# To call the function, use the function name followed by the parentheses.

# %%
# Let's call the function twice
def hello():
    print('hello world')

hello()
hello()

# %% [markdown]
# Example

# %%
def greet():
    print("Hello Siddhi")

greet()

# %% [markdown]
# examle

# %%
# Let's call the function twice
greet()
greet()

# %%
# Let's pass some argument to the function

def hello (name):
  print(f'hello {name}')    # Note, the function body is limibted by indentetation. As long as it is there, it's a part of function body.

hello('John')
hello(12)

# %% [markdown]
# Example

# %%
# Let's pass some argument to the function

def hello (name):
  print(f'hello {name}')    # Note, the function body is limibted by indentetation. As long as it is there, it's a part of function body.

hello('Siddhi')
hello(24)

# %% [markdown]
# # function has a type 'function'

# %%
print(type(hello))

# %% [markdown]
# Example

# %%
def hello (name):
  print(f'hello {name}')    # Note, the function body is limibted by indentetation. As long as it is there, it's a part of function body.

hello('John')
hello(12)
print(type(hello))

# %%
# Let's define a function that can carry out addition

def addthis(first, second):
  print(first + second)

addthis(12, 13)           # note that colab auto suggests the function name when you press ctrl + tab after writing first few letters

# %% [markdown]
# Example

# %%
# Let's define a function that can carry out addition

def addthis(first, second):
  print(first + second)

addthis(24, 13)           # note that colab auto suggests the function name when you press ctrl + tab after writing first few letters

# %%
# If the function definition has arguments, then while calling arguments must be passed, else it'll give error
# Both the calls below will give error because addthis() expects two parameters

# addthis()
# addthis(12)

# %% [markdown]
# Some more examples

# %%
def hello_you(name):
    return (f'hello {name.upper()}')
print(hello_you('Students'))

# %% [markdown]
# Example

# %%
def hello_you(name):
    return (f'hello {name.upper()}')
print(hello_you('sir ji'))

# %% [markdown]
# Return statement
#
# Almost all the time, function returns some value/data

# %%
def hi(name):
    message = "Hi "+name
    return message

name = input("Enter the name:")
print(hi(name))

# %% [markdown]
# Example

# %%
def hi(name):
    message = "Hi "+name
    return message

name = input("Enter the name:")
print(hi(name))

# %%
def add():
    a = 40
    b = 30
    c = a+b
    return c

print("The sum is:", add())

# %%
def add(a,b):
    return a+b;

a = int(input("Enter a: "))    # will give error if you pass string here
b = int(input("Enter b: "))

print("Sum = ",add(a,b))

# %% [markdown]
# # Note, sum() is a default built in function in python, that's why we are using names like add() or addthis() etc.
# # We can still use the name sum() as our function name, but it's not a good practice.
# # For more info, try help(sum) and see what you get

# %%
# Note, sum() is a default built in function in python, that's why we are using names like add() or addthis() etc.
# We can still use the name sum() as our function name, but it's not a good practice.
# For more info, try help(sum) and see what you get

# %% [markdown]
# Let's write a function to calculate interest on loan

# %%
p = int(input("Enter the principle amount? "))
r = float(input("Enter the rate of interest? "))     # sometimes interest rate could be in fraction like 8.5 or something, so float
t = int(input("Enter the time in years? "))

def simple_interest(p,t,r):
    return (p*t*r)/100


print("Simple Interest: ",simple_interest(p,r,t))

# for values of 1000, 2, 2 --> interest = 40

# %% [markdown]
# Example

# %%
# Area of Rectangle using function

length = int(input("Enter length: "))
width = int(input("Enter width: "))

def rectangle_area(length, width):
    return length * width

print("Area of Rectangle:", rectangle_area(length, width))

# %%
# For readability, you can call function by writing the name of arguments

def find_distance(speed, time):
    print(speed, time)
    return speed * time
d = find_distance(speed=10, time=3)    # like this. this is readable. This is called KEYWORD ARGUMENTS.
print(d)

d = find_distance(time=3, speed=10)     # even if order is changed, no problem. This is called KEYWORD ARGUMENTS.
print(d)

d = find_distance(3,10)     # This is not the same as above (in this case, speed=3, time=10)
print(d)
